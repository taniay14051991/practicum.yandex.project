# %% [markdown]
# Привет! Меня зовут Анна Григорьева, я буду проверять твой проект.
#
# Мы на одной стороне, моя задача - помочь тебе освоить полезные в работе дата-аналитика навыки.
# В Практикуме мы общаемся на "ты", однако если это неудобно - дай знать, и мы перейдем на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их.
#
#
# Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Зеленый - если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Желтый - то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b> Красный - грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Если ты что-то меняешь в проекте или отвечаешь на мои комментарии — обязательно пиши об этом, выделяя свои комментарии, например так:
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
#
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px"> <h1 style="color:blue; margin-bottom:20px">Итоговый комментарий ревьюера № 1</h1>
#
# Татьяна, спасибо тебе за работу. В целом, работа выполнена на хорошем уровне - отличные аналитические выводы, использование разных графиков и т.д. К сожалению, в работе есть недочеты, которые необходимо исправить. Основное - надо откорректировать актуальный период и в дальнейшем анализе использовать только его (включая раздел с тестированием гипотез). Жду исправлений, удачи!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Анна, большое спасибо за ценные советы по командам.
#
# <b>Про периоды - увлеклась и потом поторопилась, часто бывает в голове держу какуюто информацию и как само разумеещееся не вписываю (нужно избавляться от этой привычки мне 😁), по работе (при планировании нагрузки на кц) вроде давно уже привыкла брать актуальные периоды в 2-3 года, а тут не указала комент и потом переживала когда отправила что будет много вопросов почему сначала один период выбираю потом другой использую, а иногда вообще возвращаюсь к исходнику что бы кое-что проверить.
#
# <b>Хотела спросить, если сможешь ответь пожалуйста, правильно ли это, вообще для выявления тенденций глобальных, обычно смотрят большой период даных, но не весь возможный ( иногда его просто не возможно проверить из-за объема данных, так вот как такой период называется правильно? - тут это период с 1995 года до 2016 (как правило смотрят до актуальных дат) - и в нем видно что есть волны и первая большая волна пришлась на 1995-2000, с пиком в 1998, вторая волна пришлась на 2001 -2013 с пиком 2008-2009, по логике (да и по доступным в интернета данным) сейчас все еще идет третья волна и она с большим пиком чем предыдущие, я даже осмелюсь предположить, что в ближайшие годы начнется новый спад, причем значительно более резский чем в предыдущие волны.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px"> <h1 style="color:blue; margin-bottom:20px">Итоговый комментарий ревьюера № 2</h1>
#
# Татьяна, спасибо за доработку проекта! Проект стал гораздо лучше. Осталась немного доработать раздел с тестированием гипотез - исключи из среза данных для тестирования значения, на которые ты заменила пропуски в пользовательских рейтингах.
#
# Насчет твоего вопроса о названии периода, к сожалению, не совсем понимаю, о каком термине идет речь.
#
# Жду исправлений! Комментарии второй итерации обозначены как Комментарий № 2.
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px"> <h1 style="color:blue; margin-bottom:20px">Итоговый комментарий ревьюера № 3</h1>
#
# Татьяна, к сожалению, все еще надо доработать раздел с тестированием - кажется, при доработке ты немножко перестаралась с удалением пропусков и удалила строки с пропусками по не относящемуся к тесту признаку.
#
# Жду исправлений! Комментарии третье итерации обозначены как Комментарий № 3.
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px"> <h1 style="color:blue; margin-bottom:20px">Итоговый комментарий ревьюера № 4</h1>
#
# Татьяна, с учетом доработок проект принят, поздравляю!
# Переговорила с коллегами по твоему вопросу, говорят, что специального термина для обозначения такого глобального периода нет (или мы его не вспомнили :) ), обычно в исследованиях пишут, что проанализированы данные за такой-то период и далее дают обоснование, почему именно этот период выбран. Также возможно, что ты имеешь в виде репрезентативную выборку данных (это когда их генеральной совокупности отбирается часть данных, котор В целом, если тебе интересна тема циклического/волнового развития, можешь посмотреть про циклы Кондратьева,
# Удачи в освоении профессии дата-аналитика!
# </div>

# %% [markdown]
# # Исследование закономерности успешности видеоигр
#
# Из открытых источников доступны исторические данные о продажах видеоигр (до 2016 года), оценки пользователей и экспертов, жанры и платформы.
#
# Нужно выявить определяющие успешность игры закономерности.
#
# Данные иследования позволят сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Хорошее вступление, рекомендую еще более детально прописывать задачи проекта и предполагаемый ход исследования, это поможет тебе сфокусироваться на задачах и не делать лишних шагов.
# </div>

# %% [markdown]
# ### Изучение файла с данными и общей информации о данных.

# %% [markdown]
# Загрузка необходимых библиотек:

# %%
import pandas as pd#библиотека pandas
import matplotlib.pyplot as plt#импорт библиотеки matpotlib
import seaborn as sea#библиотека визуализации seaborn
from scipy import stats as st#библиотекf для проверки гипотез

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Здорово, что все импорты собраны в одной ячейке в начале проекта, так всем участникам твоего проекта будет понятно, какие библиотеки ты использовала 👍
# </div>

# %% [markdown]
# Загрузка данных из csv-файла в датафрейм в переменную data. Путь к файлу: /datasets/games.csv

# %%
pd.set_option('display.max_columns', 35)#увеличиваем количество выводимых столбцов
data = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')#открываем файл
data.head(25)#выводим первые 25 строк для анализа данных
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b>  Код для загрузки исходных данных лучше тоже писать в специально выделенной ячейке, отделяя его от рабочего кода.
#
# Еще один довольно полезный метод для вывода исходных данных - sample(). Он выводит случайную выборку из датасета (размер выборки ты можешь задать в скобках). Это может быть полезно, если ты хочешь посмотреть не на первые строки, а на случайно выбранные, иногда это помогает получить лучшее представление о данных.
# </div>

# %% [markdown]
# Основная информация о датафрейме:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# **Описание данных:**
#
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %%
data.shape# размер датасета
# Out:
# (16715, 11)

# %%
#data_len = len(data)#сохраним количество строк для оценки оставшихся данных посде предобработки
data_len = data.shape[0]
data_len
# Out:
# 16715

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠  Комментарий ревьюера:</b>  Для определения размера датасета более корректно использовать атрибут shape, которые выдает количество строк и столбцов в датасете:
#
#     data.shape
#
# Если тебе нужно только количество строк, ты можешь указать:
#
#     data.shape[0]
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: 👍спасибо
# </div>

# %% [markdown]
# Визуальное представление данных:

# %%
data.hist(figsize=(15, 15),color='darkblue');

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b>  👍
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Приведение наименования столбцов к нижнему регистру

# %%
#data = data.rename(columns = {'Name':'name',
#                              'Platform':'platform',
#                              'Year_of_Release':'year_of_release',
#                              'Genre':'genre',
#                              'NA_sales':'na_sales',
#                              'EU_sales':'eu_sales',
#                              'JP_sales':'jp_sales',
#                              'Other_sales':'other_sales',
#                              'Critic_Score':'critic_score',
#                              'User_Score':'user_score',
#                              'Rating':'rating'})
data.columns= data.columns.str.lower()
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Хорошо, что тебе знаком такой способ, но в реальном датасете у тебя может быть 100 и более столбцов.
#
# Гораздо проще использовать этот код в одну строку:
#
#     df.columns = df.columns.str.lower()
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: 👍спасибо, так действительно намного проще), почему то используя изменение регистра дальше тут про него даже не впомнила(
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  👍
# </div>

# %% [markdown]
# #### Обработка пропусков и смена типа данных

# %% [markdown]
# Подсчет пропущенныхзначений:

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# ##### Название

# %%
data[data['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Пропуски в названиях соответствуют пропускам в жанре и восстановлению не подлежат, их всего 2 строки, так что удаляем. Скорее всего это ошибка выгрузки.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Верное решение 👍
# </div>

# %% [markdown]
# ##### Год выхода

# %%
data[data['year_of_release'].isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
data[data['name'] == 'FIFA Soccer 2004']#проверка есть ли даная игра на других платформах
# Out:
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 377    FIFA Soccer 2004      PS2              NaN  Sports      0.59      2.36
# 2606   FIFA Soccer 2004       XB           2003.0  Sports      0.24      0.49
# 12029  FIFA Soccer 2004       GC           2003.0  Sports      0.05      0.01
# 13086  FIFA Soccer 2004      GBA           2003.0  Sports      0.04      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 377        0.04         0.51          84.0        6.4      E
# 2606       0.00         0.05          82.0        8.2      E
# 12029      0.00         0.00          83.0        6.2      E
# 13086      0.00         0.00          82.0        7.9      E

# %% [markdown]
# ~Попробуем восстановить значения по имеющимся данным:~

# %%
#datag = data.groupby('name')['year_of_release'].mean()#создание списка по названию игр со средним по году выхода
#datag.head()

# %%
#for t in datag.index:
#    data.loc[(data['name'] == t) & (data['year_of_release'].isna()), 'year_of_release'] = \
#    data.loc[(data['name'] == t), 'year_of_release'].mean()

# %%
#data[data['name'] == 'FIFA Soccer 2004']#проверка замены

# %%
#data['year_of_release'].isna().sum()

# %% [markdown]
# ~Дата была восстановлена почти у половины пропусков в годе выхода.~
#
# Проверим сколько данных имеет пропус года выхода:

# %%
data['year_of_release'].isna().sum()/data_len# % пропусков в дате выхода
# Out:
# 0.01609332934489979

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Не совсем корректно заменять пропуски в годе релиза на среднее. Хорошо, что ты стараешься восстановить данные таким способом, но разреши дать тебе совет:
#
# - проверять, какой % занимают пропуски от общего количества записей по этому признаку,
# - сразу удалять такую малую долю пропусков для экономии времени.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: По началу я эти даные не задумываясь удалила, но так как у меня по техническим причинам выполнение проекта встало на два дня, а вот голову никто не выключил мне, пришла 'гениальная' мысль попробывать востановить эти данные, хотя конечно сразу понятно было, что эта затея неоправданно трудозатратна.
# </div>

# %% [markdown]
# Дата выхода игры пропущена случайным образом, восстановление этих данных в теории возможно, требуется создать отдельный список с пропущенными значениями и произвести их более детальный анализ,но так как пропусков по дате выхода всего ~0,9%~ 1.6% принимаем решение о их удалении из данных, так как их восстановление трудозатрано и неоправданно из-за малого объема данных.

# %% [markdown]
# Удаляем пропуски в годе выхода и имени:

# %%
data = data.dropna(subset=['name','year_of_release'])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  👍
# </div>

# %% [markdown]
# Год это целое число, поэтому изменяем тип данных.

# %%
data['year_of_release'] = data['year_of_release'].astype('int32')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b>  👍
# </div>

# %%
#распределение выхода игр по годам,после внесения изменений
(data['year_of_release']
 .value_counts()
 .sort_index(ascending=True)
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Количественное распределение по годам'));

# %% [markdown]
# ##### Оценки критиков

# %%
(data[data['critic_score'].isna()]
 .pivot_table(index = 'year_of_release',values = 'name', aggfunc = 'count')
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение пропусков оценки критиков по годам')
);

# %%
data['critic_score'].isna().sum()/data_len# % пропусков в оценки критиков
# Out:
# 0.5061920430750823

# %%
pd.unique(data['critic_score'])#уникальные значения оценок критиков
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %% [markdown]
# Пропуски в оценки критиков составляют половину данных и распределены равномерно по данным, удалять их нельзя. В принципе, пропуски в данном поле логичны так как ежегодно выходит большое количество инди-проектов которые не удостаиваются большого внимания, да и оценки критиков подвергается не каждая вышедшая на рынок игра.
#
# Так как в уникальных значениях данного столбца, значение "0" отсутствует, можно условно принять nan за 0 и произвести замену.
#
# По уникальным значениям видно, что столбец содержит только целые числа.

# %%
data['critic_score'] = data['critic_score'].fillna(0)#замена пропусков на 0

# %%
data.loc[~data['critic_score'].isna(), 'critic_score'] = data.loc[~data['critic_score'].isna(), 'critic_score'].astype('int32')

# %%
(data[data['critic_score'] != 0]['critic_score']
 .value_counts()
 .sort_index(ascending=True)
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение оценки критиков без 0 значений'));

# %% [markdown]
# Аномальных значений (более 100) нет

# %% [markdown]
# ##### Оценки пользователей

# %%
(data[data['user_score'].isna()]
 .pivot_table(index = 'year_of_release',values = 'name', aggfunc = 'count')
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение пропусков оценки пользователей по годам')
);

# %%
data['user_score'].isna().sum()/data_len# % пропусков в оценки пользователей
# Out:
# 0.3951540532455878

# %%
pd.unique(data['user_score'])
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
data[data['user_score'] == 'tbd'].head()
# Out:
#                                name platform  year_of_release   genre  \
# 119                   Zumba Fitness      Wii             2010  Sports
# 301  Namco Museum: 50th Anniversary      PS2             2005    Misc
# 520                 Zumba Fitness 2      Wii             2011  Sports
# 645                    uDraw Studio      Wii             2010    Misc
# 718                 Just Dance Kids      Wii             2010    Misc
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# 119      3.45      2.59       0.0         0.66             0        tbd      E
# 301      2.08      1.35       0.0         0.54            61        tbd   E10+
# 520      1.51      1.03       0.0         0.27             0        tbd      T
# 645      1.65      0.57       0.0         0.20            71        tbd      E
# 718      1.52      0.54       0.0         0.18             0        tbd      E

# %%
len(data[data['user_score'] == 'tbd'])#количество строк со значением tbd
# Out:
# 2376

# %% [markdown]
# tbd - неопределенное значение или ,в данном случае, ~0~ -1, заменим эти значения:

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  tbd = to be determined, т.е. рейтинг еще не присвоен. Логично обработать эти значения так же, как nan.
# </div>

# %%
data.loc[data['user_score'] == 'tbd', 'user_score'] = -1# замена занчений tbd на 0
data['user_score'] = pd.to_numeric(data['user_score'], errors='raise')#замена типа данных значений на вещественные

# %% [markdown]
# Пропуски в оценки пользователей составляют 40%, даное значение логично, пользователи оценивают не все игры, многие могут остаться и вовсе без внимания игроков, так как ежегодно на рынок выходит множество инди-проектов. Пропусков тут меньше чем в оценке экспертов, поскольку пользователи с большей вероятностью оценят инди-проект чем эксперты на него наткнуться. Данные пропуски удалять нельзя и заменять на 0 нельзя, так как в уникальных значениях содержится "0", заменять на медианное или среднее значение по жанру или году выхода тоже не корректно, в данном случае пропуск сам по себе является значением - игру не оценивали и как следствие мало в неё играли, т.е игра не популярна.
# <div class="alert alert-block alert-info">
# <b>Для дальнейшего анализа заменим пропуски значенпием -1, что позволит нам не потерять данные дальнейшем анализе
# </div>

# %%
data['user_score'] = data['user_score'].fillna(-1)#замена пропусков на -1

# %%
(data[data['user_score'] != -1]['user_score']
 .value_counts()
 .sort_index(ascending=True)
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение оценки пользователя без 0 значений'));

# %% [markdown]
# Аномальных значений (более 10) нет

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  В исходных данных есть игры, которым пользователи поставили 0 (возможно, это были очень плохие игры), поэтому присваивать это значение играм без рейтинга не корректно (и исключать из графика тоже). Для замены пропусков можно выбрать аномально большое или отрицательное значение, чтобы не перепутать эти значения с реальными.
# Также у тебя в данных есть nan, следует сразу обработать пропуски.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: По началу я эти даные не задумываясь удалила, но так как у меня по техническим причинам выполнение проекта встало на два дня, а вот голову никто не выключил мне, пришла 'гениальная' мысль попробывать востановить эти данные, хотя конечно сразу понятно было, что эта затея неоправданно трудозатратна.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  Теперь все верно. Совет: можно было сделать замену типа данных, используя метод astype().
# </div>

# %% [markdown]
# ##### Рейтинг

# %%
print('Количество пропусков в рейтинге по жанрам игр')
plt.rcParams['figure.figsize']=(8,8)
sea.barplot( y = data[data['rating'].isna()].pivot_table(index = ['genre'],values = 'name', aggfunc = 'count').index,
            x = data[data['rating'].isna()].pivot_table(index = ['genre'],values = 'name', aggfunc = 'count')['name'],
           color='darkblue',
           );
# Out:
# Количество пропусков в рейтинге по жанрам игр

# %%
data['rating'].isna().sum()/data_len# % пропусков в оценки пользователей
# Out:
# 0.3994017349685911

# %%
pd.unique(data[data['genre'] == 'Action']['rating'])#уникальные значения рейтинга для категории Экшен
# Out:
# array(['M', nan, 'E', 'T', 'E10+', 'AO', 'EC'], dtype=object)

# %%
pd.unique(data['rating'])#уникальные значения рейтинга для всех данных
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# В рейтинге 40% пропусков, их нельзя удалять. Не все игры проходят должные проверки и не все платформы требуют указывать разработчиков категорию. Так что такое количество пропусков вполне оправдвнно.
#
# Заменить пропуски на какие-то уникальные значения не представляется возможным так как определить рейтинг по названию игры или жанру не возможно. Так же можно сказать, что используемые обозначения рейтинга характерны только для Entertainment Software Rating Board (ESRB) используемой только на территории США и Канады и в редких случаях в других странах, а занчит пропуски можно условно заменить на tbd (неопределенно), для удобства анализа данного показателя.

# %%
data['rating'] = data['rating'].fillna('tbd')#замена пропусков на tbd

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Приемлемое решение, но все же советую посмотреть на расшифровку аббревиатуры tbd - ты совершенно верно отмечаешь, что рейтинг используется в США и Канаде, и его не используют (и не планируют использовать) в других странах.  👍
# </div>

# %% [markdown]
# Проверяем оставшиеся пропуски:

# %%
data.isna().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# Проверяем изменения в типе данных:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int32
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  int32
#  9   user_score       16444 non-null  float64
#  10  rating           16444 non-null  object
# dtypes: float64(5), int32(2), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b>  👍
# </div>

# %% [markdown]
# #### Обработка дубликатов

# %% [markdown]
# Явные дубликаты:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Неявные дубликаты:

# %% [markdown]
# Проверим уникальные значения по столбцам с типом данных "object":

# %%
data['name'] = data['name'].str.lower()#приведем все названия игр к нижнему регисру
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      Wii             2006        Sports     41.36
# 1         super mario bros.      NES             1985      Platform     29.08
# 2            mario kart wii      Wii             2008        Racing     15.68
# 3         wii sports resort      Wii             2009        Sports     15.61
# 4  pokemon red/pokemon blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45            76         8.0      E
# 1      3.58      6.81         0.77             0        -1.0    tbd
# 2     12.76      3.79         3.29            82         8.3      E
# 3     10.93      3.28         2.95            80         8.0      E
# 4      8.89     10.22         1.00             0        -1.0    tbd

# %%
#len(pd.unique(data['name']))#количество уникальных названий игр
data['name'].nunique()
# Out:
# 11426

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Для расчета количества уникальных значений по признаку лучше использовать метод nunique():
#
# data['name'].nunique()
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: 👍спасибо
# </div>

# %%
pd.unique(data['platform']) #все платформы на которые выходят игры
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
pd.unique(data['genre'])#все жанры игр
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
pd.unique(data['rating'])#все категории игр
# Out:
# array(['E', 'tbd', 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'],
#       dtype=object)

# %% [markdown]
# По платформам, жанрам и категориям дублей нет. А вот по названиям нужно проверить, скорее всего это строки с разными платформами.

# %%
data.duplicated('name').sum()
# Out:
# 5018

# %%
data[data.duplicated('name')].sort_values(by='name', ascending=True).head(15)
# Out:
#                                                     name platform  \
# 3862                                frozen: olaf's quest       DS
# 4475                              007: quantum of solace      PS2
# 3120                              007: quantum of solace      Wii
# 9507                              007: quantum of solace       DS
# 14658                             007: quantum of solace       PC
# 1785                              007: quantum of solace      PS3
# 2243                        007: the world is not enough       PS
# 15656                                  11eyes: crossover      PSP
# 10076                   18 wheeler: american pro trucker       GC
# 12283                                   187: ride or die       XB
# 9966   2 in 1 combo pack: sonic heroes / super monkey...     X360
# 13302                                2002 fifa world cup       GC
# 7820                                 2002 fifa world cup       XB
# ...

# %% [markdown]
# Выходит что повторы в названиях игр - это игры которые выходили на разные платформы и по сути дублями в таком случае не являются, так как несут разные данные.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Здесь можно было проверить дубликаты по 'name', 'platform', 'year_of_release', 'genre', например, вот так:
#
#     games[games.duplicated(subset=['name', 'platform', 'year_of_release', 'genre'], keep=False)]
#
# Это "желтый" комментарий, т.е. исправлять его в данном проекте не обязательно, но хотелось бы, чтобы ты обратила на это внимание. Возможно, это пригодится тебе в работе над реальным проектом. Подумай, что это может означать и как можно обработать такой дубликат?
# </div>

# %% [markdown]
# Проверим дубликаты которые могли бы появиться в случае объединения данных из разных магазинов видеоигр ( при таких дублях все даные, кроме даных о продажах, будут полностью совпадать):

# %%
data[data.duplicated(subset=['name', 'platform', 'year_of_release', 'genre'], keep=False)]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    madden nfl 13      PS3             2012  Sports      2.11      0.22
# 16230  madden nfl 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 604         0.0         0.23            83         5.5      E
# 16230       0.0         0.00            83         5.5      E

# %%
# Просумируем чисельные значения строк (они не равны, поэтому здесь можно воспользоваться циклом с условием) 
#и заменим одну из строк
#в случае если бы тахих дублей было бы больше можно было бы написать функцию
seq = data.columns
value = []
for ind in seq:
    if data.loc[604,ind] == data.loc[16230,ind]:
        value.append(data.loc[604,ind])
    else:
        value.append(data.loc[604,ind]+data.loc[16230,ind])
#row_new = dict.fromkeys(seq, value)
data.loc[604] = value

# %%
#удалим дубль
data = data.drop_duplicates(subset = ['name', 'platform', 'year_of_release', 'genre'], keep = 'first', inplace = False)

# %% [markdown]
# Проверим нет ли дублей с разнящися жанром (такое бывает если у игры указывается несколько жанров и её продают в нескольких магазинах):

# %%
data[data.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: 👍спасибо, вообще обычно в работе стараюсь искать такие дубли и мысль о них была, но вот знание синтаксиса (тут нужно больше пракики) подвело и мои пробы результата не дали, поэтому для отправки финального проэкта я их удалила, но с этой командой смогла восстановить.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  Здорово, что нашла и обработала такой дубликат 👍
# </div>

# %% [markdown]
# Проверим сколько данных было удалено в ходе предобработки данных:

# %%
(data_len-len(data))/data_len#доля удаленных даных после проведения предобработки
# Out:
# 0.016272808854322463

# %% [markdown]
# Удалили ~0,9%~ 1.6% что приемлимо для обработки.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Отлично, что проверяешь % потерянных данных 👍
# </div>

# %% [markdown]
# #### Подсчёт и добавление в таблицу новых столбцов

# %% [markdown]
# Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец:

# %%
data['world_sales'] = data['na_sales']+data['eu_sales']+data['jp_sales']+data['other_sales']

# %%
data.head(10)#просмотр добавленных данных
# Out:
#                         name platform  year_of_release         genre  \
# 0                 wii sports      Wii             2006        Sports
# 1          super mario bros.      NES             1985      Platform
# 2             mario kart wii      Wii             2008        Racing
# 3          wii sports resort      Wii             2009        Sports
# 4   pokemon red/pokemon blue       GB             1996  Role-Playing
# 5                     tetris       GB             1989        Puzzle
# 6      new super mario bros.       DS             2006      Platform
# 7                   wii play      Wii             2006          Misc
# 8  new super mario bros. wii      Wii             2009      Platform
# 9                  duck hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45            76         8.0      E
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b>  👍
# </div>

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Распределение выпуска игр по годам

# %% [markdown]
# Задачи:
#
# - [x] Посмотреть, сколько игр выпускалось в разные годы.
# - [x] Важны ли данные за все периоды?
# - [x] Взять данные за соответствующий актуальный период.
# - [x] Выбрать актуальный период данных. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - [x] Не учитывайте в работе данные неактуального периода.

# %%
#создадим сводную таблицу по годам
year_data = data.pivot_table(index = 'year_of_release',values = 'name', aggfunc = 'count')
year_data['percent_total'] = (year_data['name']/year_data['name'].sum())*100
year_data = year_data.rename(columns = {'name':'count','percent_total':'percent_total'})
year_data
# Out:
#                  count  percent_total
# year_of_release
# 1980                 9       0.054735
# 1981                46       0.279754
# 1982                36       0.218938
# 1983                17       0.103387
# 1984                14       0.085143
# 1985                14       0.085143
# 1986                21       0.127714
# 1987                16       0.097306
# 1988                15       0.091224
# 1989                17       0.103387
# 1990                16       0.097306
# 1991                41       0.249346
# 1992                43       0.261509
# 1993                60       0.364897
# 1994               121       0.735875
# 1995               219       1.331874
# 1996               263       1.599465
# 1997               289       1.757587
# 1998               379       2.304932
# 1999               338       2.055586
# 2000               350       2.128565
# 2001               482       2.931339
# 2002               829       5.041659
# ...

# %%
(year_data['count']
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Количественное распределение выпуска игр по годам'));

# %%
year_data[year_data['percent_total'] <= 1.0].sum()
# Out:
# count            486.000000
# percent_total      2.955665
# dtype: float64

# %% [markdown]
# С данными менее чем за 1995 год можно растаться так как они мало влияют на статистику

# %%
data_relevant = data.loc[data['year_of_release'] >=1995].reset_index(drop=True)

# %%
(data_relevant
 .pivot_table(index = 'year_of_release',values = 'world_sales', aggfunc = 'sum')
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение продаж копий игр по годам в актуальном периоде')
);

# %% [markdown]
# **Вывод:**
#
#     Пик игровой индустрии, как по числу продаж копий так и по выходу игр, пришёлся на 2008-2009 год, после наблюдается стабильный спад, вероятнее всего это связанно с тем, что после этого года компании чаще стали выпускать дополнения и ремейки, нежили новые игры. Но эта гипотиза не может быть проверена на имеющихся данных, так как исходный файл хранит данные без информации о дополонениях и перезапусках.
#
#     До 1995 года было выпущено всего 3% игр от иследуемого периода, что несущественно для анализа и эти данные можно отбросить.
#
#     Вероятно актуальный период может уменьшится после иследования платформ.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  В этом разделе тебе нужно было
# 1) Построить графики продаж по годам по нескольким интересным платформам - определить средний жизненный цикл платформ, посмотреть, через сколько лет в среднем на платформах начинается спад продаж.
#
# 2) Определить актуальный период и в дальнейшем анализе использовать только его. При определении актуального периода держи в фокусе цель проекта - сделать рекомендации на следующий год + учитывай специфику отрасли (как быстро адаптируется отрасль к изменениям трендов, можно ли брать для нашей задачи период более 5 лет или лучше выбрать более короткий период  и т.д.)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: не совсем поняла что делать с данным коментом, ведь не очень желательно изменять структуру проекта после первой проверки что-бы ревьюер не запутался, но у меня дальше в проекте есть определение жизненого цикла платформ со всеми выводами по продажам. Мне поднять этот кусок сюда?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b> В задачах следующего раздела у тебя указано, что не следует учитывать неактуальный период, но он еще не определен. Переносить не нужно, вижу, что ниже ты откорректировала актуальный период и теперь все верно.  👍
# </div>

# %% [markdown]
# #### Распределение игр по платформам

# %% [markdown]
# Задачи:
#
# - [x] Не учитывайте в работе данные неактуального периода.
# - [x] Посмотреть, как менялись продажи по платформам.
# - [x] Выберать платформы с наибольшими суммарными продажами и построить распределение по годам.
# - [x] За какой характерный срок появляются новые и исчезают старые платформы?
# - [x] Какие платформы лидируют по продажам, растут или падают?
# - [x] Выберать несколько потенциально прибыльных платформ.
# - [x] Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описать результат
# - [x] Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы. Соотнести выводы с продажами игр на других платформах

# %% [markdown]
# Проверим распределение игр по платформам и годам выхода:

# %%
#используем для этой проверки неизмененный датасет
sea.set()
plt.rcParams['figure.figsize']=(15,10)
sea.scatterplot(x="year_of_release", 
                y="platform",hue="genre",
                size="genre",
                data=data,
                sizes=(20, 300),
               );

# %%
sea.boxplot(x="year_of_release",
            y="platform", 
            data = data,
            color='blue',
            width = 1,
            fliersize = 1,
            linewidth = 1
            );

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Интересный график, здорово, что пробуешь строить разные виды графиков.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b> Для нашей задачи особенно интересно посмотреть на распределение продаж по платформам. Здесь более уместен будет boxplot.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Мне этот график показался каким то не очень красивым, хотя это субъективное мнение, поэтому попыталась найти какое-то более оригинальное решение)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера № 2:</b>  Boxplot хорошо иллюстрирует распределение данных, на нем хорошо видны хвосты и выбросы, а также медианные значения - так мы можем сразу понять основные различия между платформами. Где-то медианные значения существенно выше, где-то совсем мало выбросов - все это может быть полезно при планировании деятельности нашей компании.
#
# Сейчас твой график отражает не продажи, а количество релизов(?).
#
# Совет на будущее: пожалуйста, не выбирай слишком темный цвет для этого графика, так почти не видны медианные значения (или выделяй их по-другому).
# </div>

# %%
data.groupby('platform')['world_sales'].describe().sort_values('count',ascending=False)
# Out:
#            count      mean       std   min     25%    50%     75%    max
# platform
# PS2       2127.0  0.579953  1.138461  0.00  0.0800  0.230  0.5600  20.81
# DS        2121.0  0.378491  1.436042  0.01  0.0500  0.110  0.2700  29.80
# PS3       1305.0  0.713670  1.403477  0.00  0.1100  0.280  0.7600  21.05
# Wii       1286.0  0.692986  3.165022  0.01  0.0900  0.190  0.4875  82.54
# X360      1232.0  0.780227  1.632122  0.01  0.1100  0.280  0.7700  21.82
# PSP       1193.0  0.242691  0.522019  0.01  0.0300  0.090  0.2300   7.68
# PS        1190.0  0.611412  1.056807  0.01  0.1100  0.260  0.6600  10.95
# PC         957.0  0.267252  0.679745  0.01  0.0200  0.050  0.1700   8.01
# GBA        811.0  0.385795  0.899654  0.01  0.0550  0.160  0.3900  15.84
# XB         803.0  0.313288  0.539309  0.01  0.0600  0.150  0.3400   8.48
# GC         542.0  0.362970  0.693974  0.01  0.0600  0.150  0.3675   7.06
# 3DS        512.0  0.503535  1.441271  0.01  0.0500  0.120  0.3325  14.60
# ...

# %% [markdown]
# Для того что бы график был более информативным выбросы придется отсечь:

# %%
sea.boxplot(x="world_sales",
            y="platform", 
           # hue='world_sales',
            data = data.loc[data['world_sales'] < 5,["year_of_release","platform",'world_sales']],
            color='blue',
            width = 1,
            fliersize = 1,
            linewidth = 1
            );

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v2: Вероятно такой график будет более правильный.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Добавим еще график с общей тенденцией продаж по миру
# </div>

# %%
#проверим распределение пародаж копий игр по миру
(data
 .pivot_table(index = 'year_of_release',values = 'world_sales', aggfunc = 'sum',fill_value=0)
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение мировых продаж по годам')
);

# %%
#проверим распределение игр на ПК
(data[data['platform'] == 'PC']
 .pivot_table(index = 'year_of_release',values = 'platform', aggfunc = 'count',fill_value=0)
 .plot(kind='bar' ,figsize=(15,5),color='darkblue')
 .set(title='Распределение выпуска игр на РС по годам')
);

# %% [markdown]
# **Вывод:**
#
# Как видно по графику такие платформы как Atari 2600(2600),первая Nintendo(NES) и SEGA(GEN) устарели до 1995 года (на самом деле в них до сих пор играют, только вот игры не выпускают).
# Однако, если не счить игры на ПК(PC), сушествующие сейчас платформы появильсь только после 2005 года.
# Учитывая это, то что пик продаж пришёлся на 2008-2009 и то, что игры на ПК до 2005 года выходили существенно реже чем после, для прогназирования даных на будиющие периоды достаточно данных с 2005 года.
#
# <div class="alert alert-block alert-info">
# Так же по графикам видна нарастающая полнообразная структура интреса к видиоиграм, последняя волна закончилась в 2013 году, сейчас идет постипенное наростание продаж, так же видно, что продолжительность и интенсивность волн со временем имеет тенденцию к росту, а значит можно сказать, что для прогнозирования 2017 года будет достаточно данных последних 2-3 лет. Так как данные за 2016 год явно не полные, возьмем 2014-2016 годы.
# </div>

# %%
data_relevant = data.loc[data['year_of_release'] >=2014].reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды.
#
# Пожалуйста, откорректируй актуальный период и в дальнейшем анализе используй только его (включая тестирование гипотез).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Тут меня смутили 'волны' интереса в графике исходного датасета, в моей практике планирования такого не было, точнее не совсем так, было но в рамках одного года - т.е сезонные, а вот в рамках глобальных тенденций - только рост, вот я тут и замялась убирать явно интересные даные, хотя в дальнейшем делала выборки на последние 2 года
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b> Теперь актуальный период определен корректно.
# </div>

# %%
#проверим долю пропусков в оценки пользователя в данных за актуальный период
#data_relevant['user_score'].isna().sum()/len(data_relevant)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Поясни, пожалуйста, для чего здесь этот код? </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Вообще не нужен, хэто я сомневалась убирать пропуски в данных или заменять и поэтому решила тут проверить что там в актуальном периоде, но если все заменить еще в начале, то тут этот код лишний😊
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  👍
# </div>

# %% [markdown]
# Все еще много пропусков, но существенно меньще чем в основном масиве данных

# %% [markdown]
# Определим лидеров по продажам числа копий в актуальном периоде:

# %%
data_relevant.groupby('platform')['world_sales'].agg(['sum','count']).sort_values('sum',ascending=False)
# Out:
#              sum  count
# platform
# PS4       288.15    376
# XOne      140.36    228
# 3DS        86.68    212
# PS3        68.18    219
# X360       48.22    111
# WiiU       42.98     73
# PC         27.05    151
# PSV        22.40    295
# Wii         5.07     11
# PSP         0.36     13

# %% [markdown]
# По данным явно выделяются три лидера с продажами более 900 милионов копий, но разберем первую 10ту, при этом количество вышедших игр не влияет на количество копий:
#
# - X360 - Xbox 360 приставка компании Microsoft
# - PS3 - PlayStation 3 приставка компании Sony
# - Wii - 7-ое поколение приставок компании Nintendo
# - DS -  портативная игровая консоль компании Nintendo
# - PS2 - PlayStation 2 приставка компании Sony
# - PS4 - PlayStation 4 приставка компании Sony
# - PSP - PlayStation Portable приставка компании Sony
# - 3DS -  портативная игровая консоль компании Nintendo
# - PC - персональный компьютер (самая тежело оцениваемая категоря по продажам лицензированных копий по причине хорошо развитого пиратсва)
# - XOne - Xbox One приставка компании Microsoft

# %% [markdown]
# Распределение продаж копий по годам 10 лидерующих платформ:

# %%
top_10_sellers_sum = data_relevant.pivot_table(
    index = 'platform',
    columns = 'year_of_release', 
    values = 'world_sales', 
    aggfunc = 'sum',
    fill_value=0,
    margins=True)
#top_10_sellers_sum = top_10_sellers_sum[top_10_sellers_sum['All'] > 100].sort_values(by = 'All',ascending=False)
top_10_sellers_sum = top_10_sellers_sum.sort_values(by = 'All',ascending=False)
top_10_sellers_sum
# Out:
# year_of_release    2014    2015    2016     All
# platform
# All              331.53  267.98  129.94  729.45
# PS4              100.00  118.90   69.25  288.15
# XOne              54.07   60.14   26.15  140.36
# 3DS               43.76   27.78   15.14   86.68
# PS3               47.76   16.82    3.60   68.18
# X360              34.74   11.96    1.52   48.22
# WiiU              22.03   16.35    4.60   42.98
# PC                13.28    8.52    5.25   27.05
# PSV               11.90    6.25    4.25   22.40
# Wii                3.75    1.14    0.18    5.07
# PSP                0.24    0.12    0.00    0.36

# %%
top_10_sellers_sum = top_10_sellers_sum[top_10_sellers_sum.index != 'All']# удалим стоку с суммарными значениями по годам
sea.set()
plt.rcParams['figure.figsize']=(15,10)
sea.heatmap(top_10_sellers_sum.drop(columns = 'All'), annot=True, fmt="g");

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Пожалуйста, поясни, почему ты решила выбрать heatmap для иллюстрации динамики продаж.
#
# Для того, чтобы уйти от scientific notation (e) в отображении чисел на heatmap, можно использовать параметр fmt (см пример ниже). Ссылка на документацию https://docs.python.org/3/library/string.html?highlight=string#formatspec
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Я попробывала столбчатую диаграмму с объединением , но вышло как то ужасно нагруженно и не информативно, попробывав теплловую диаграмму результат мне понравился больше, это конечно субъективно, но мне показалось что она более наглядная.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b> Для таких целей хорошо подходят линейные графики. У вас дальше по программе будет раздел по визуализации данных, и там вы более подробно узнаете о разных видах графиков и библиотеках для их построения.
#
# Для выбора наиболее подходящей визуализации для разных случаев можно использовать постер из книги Александра Богачева "Графики, которые убеждают всех" (тоже ее советую)
#
#     https://fearless-mink-812.notion.site/6c5ae8ceb8b5411e907c93c9b5e6a44e
#
# </div>

# %%
# пример к комментарию ревьюера
sea.heatmap(top_10_sellers_sum.drop(columns = 'All'), annot=True, fmt='.1f');

# %% [markdown]
# Распределение выпуска игр по годам 10 лидерующих платформ:

# %%
top_10_sellers_count = data_relevant.pivot_table(
    index = 'platform',
    columns = 'year_of_release', 
    values = 'world_sales', 
    aggfunc = 'count',
    fill_value=0,
    margins=True)
top_10_sellers_count = top_10_sellers_count.sort_values(by = 'All',ascending=False)
top_10_sellers_count
# Out:
# year_of_release  2014  2015  2016   All
# platform
# All               581   606   502  1689
# PS4                75   137   164   376
# PSV               100   110    85   295
# XOne               61    80    87   228
# PS3               108    73    38   219
# 3DS                80    86    46   212
# PC                 47    50    54   151
# X360               63    35    13   111
# WiiU               31    28    14    73
# PSP                10     3     0    13
# Wii                 6     4     1    11

# %%
top_10_sellers_count = top_10_sellers_count[top_10_sellers_count.index != 'All']# удалим стоку с суммарными значениями по годам
sea.set()
plt.rcParams['figure.figsize']=(15,10)
sea.heatmap(top_10_sellers_count.drop(columns = 'All'), annot=True, fmt="g");

# %% [markdown]
# **Вывод:**
#
# Как видно из графиков пики продаж по копиям игр не всегда связаны с количеством выпускаемых игр в этот год на конкретную платформу.
#
# Так же по тенденции видно, что данные за 2016 год не полные.
#
# Основным лидиром по производимым играм и продажам на момент формирования датасета является PS4, остальные платформы явно сдают позиции, так же намечается очередной рост интреса к PC играм (не Ведьмак ли тому причина, на самом деле нет, но 2015 и 2016 годы были определенно "золотыми" для компьютерных игр)

# %% [markdown]
# Проверим срок жизни платформ используя исходный датасет:

# %%
year = data['year_of_release'].max() - data['year_of_release'].min()#сколько лет в иследуемом периоде
year
# Out:
# 36

# %%
platform_lifespan = data.pivot_table(
    index = 'platform', 
    values = 'year_of_release', 
    aggfunc = ['min', 'max'])
platform_lifespan['lifespan'] = platform_lifespan['max'] - platform_lifespan['min']
platform_lifespan
# Out:
#                      min             max lifespan
#          year_of_release year_of_release
# platform
# 2600                1980            1989        9
# 3DO                 1994            1995        1
# 3DS                 2011            2016        5
# DC                  1998            2008       10
# DS                  1985            2013       28
# GB                  1988            2001       13
# GBA                 2000            2007        7
# GC                  2001            2007        6
# GEN                 1990            1994        4
# GG                  1992            1992        0
# N64                 1996            2002        6
# NES                 1983            1994       11
# NG                  1993            1996        3
# PC                  1985            2016       31
# PCFX                1996            1996        0
# PS                  1994            2003        9
# PS2                 2000            2011       11
# ...

# %%
#продолжительность жизни платформ
sea.barplot(x='lifespan', y=platform_lifespan.index, data = platform_lifespan,color='darkblue');

# %%
platform_lifespan['lifespan'].median()
# Out:
# 6.0

# %% [markdown]
# **Вывод:**
#
# Средняя (в данном случае медианная) продолжительность жизни одной платформы 8 лет.
#
# Есть в исходных данных и "невыстрелившие" проекты, такие как TurboGrafx-16 (TG16) и PC-FX от японской NEC и GG(Game Gear) от Sega, игра ны которые выходили токо в год выпуска на рынок платформы, и PC (ПК) - можно считать долгожителем среди видиогейменга из-за своей доступности и универсальности для широкого потребителя.
#
# Как видно из распределения выхода игр на разные платформы по годам заметна тенденция, что количество выпускаемых игр и продоваемость их копий падает на текущей версии платформы от конкретной компании после анонса нового движка, пик продаж приходится на 3-5 год после выхода консоли в продажу, при этом продажи на предыдущих версиях постепеннно снижаются и к пику продоваемости новой версии производство игр на старую платформу закрывается.
#
# Тут таже стоит отметить, что скорее всего указано финальное количество проданных копий на менент создания выгрузки. Так как в данных явно нет динамики продоваемости копий игры по годам, то сложно оценить реальную продолжительность жизни платформ.
# В данном случае, коректно говорить, что производители видиоигр и компании разработчики игровых платфор намеренно закрывают выпуск игр на старые версии в угоду продвижения новых продуктов, а вот модинг и эмуляторы никто учесть не может и сами игры могут жить намного дольше даже платфор на которые были выпущены.

# %% [markdown]
# **Расмотрим отдельно XOne и PS4, как недавно вышедшие (для имеющегося датасета) платформы нового поколения**

# %%
data_relevant[data_relevant['platform'] == 'XOne'].describe()
# Out:
#        year_of_release    na_sales    eu_sales    jp_sales  other_sales  \
# count       228.000000  228.000000  228.000000  228.000000   228.000000
# mean       2015.114035    0.356447    0.202851    0.001404     0.054912
# std           0.799325    0.634756    0.371972    0.005289     0.095065
# min        2014.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2014.000000    0.030000    0.020000    0.000000     0.000000
# 50%        2015.000000    0.100000    0.070000    0.000000     0.020000
# 75%        2016.000000    0.352500    0.210000    0.000000     0.052500
# max        2016.000000    4.590000    2.190000    0.040000     0.680000
#
#        critic_score  user_score  world_sales
# count    228.000000  228.000000   228.000000
# mean      50.166667    4.496053     0.615614
# std       35.949283    3.598670     1.046513
# min        0.000000   -1.000000     0.010000
# 25%        0.000000   -1.000000     0.050000
# 50%       67.000000    6.100000     0.205000
# ...

# %%
data_relevant[data_relevant['platform'] == 'PS4'].describe()
# Out:
#        year_of_release    na_sales    eu_sales    jp_sales  other_sales  \
# count       376.000000  376.000000  376.000000  376.000000   376.000000
# mean       2015.236702    0.262261    0.345851    0.039947     0.118298
# std           0.762336    0.583439    0.815480    0.067048     0.256506
# min        2014.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2015.000000    0.000000    0.000000    0.000000     0.000000
# 50%        2015.000000    0.050000    0.070000    0.015000     0.020000
# 75%        2016.000000    0.240000    0.280000    0.050000     0.102500
# max        2016.000000    6.030000    6.310000    0.490000     2.380000
#
#        critic_score  user_score  world_sales
# count    376.000000  376.000000   376.000000
# mean      45.486702    4.038298     0.766356
# std       36.202539    3.918064     1.614969
# min        0.000000   -1.000000     0.010000
# 25%        0.000000   -1.000000     0.057500
# 50%       64.000000    6.100000     0.185000
# ...

# %% [markdown]
# **Вывод:**
#
# И PS4 и XOne вышли на рынок в 2013 году, обе платформы к 2016 году вошли в пик продоваемости игр. Из исторических данных мы знаем, что Microsoft и Soni начали борьбу приставок и в 2016 были анонсированы и выпушены  Xbox One S и PlayStation 4 Pro, координальной смены продукта не последовало, новые выерсии и несколько последующих не требовали смены библиотеки игр или адаптации вышедших игр со стороны разработчиков,а значит можно смело прогнозировать на 2017 год рост продаж копий игр. Рост можно прогназировать и на другие платформы (так как по общей тенденции видно что начался новая волна активности в производстве видиоигр и интереса к ним.

# %% [markdown]
# **Расмотрим топ продаж копий игр за последний год**

# %%
data_topgame2016 = (data_relevant
                    .query('year_of_release == 2016')
                    .sort_values(by='world_sales', ascending=False)
                    .reset_index(drop=True)
                    .head(15)
                   )
name_game = set(data_topgame2016['name'].values)


data_2016 = (data_relevant
                    .query('(year_of_release == 2016) and (name.isin(@name_game))')
                    .sort_values(by='world_sales', ascending=False)
                    .reset_index(drop=True)
                   )
#ax = sea.boxplot(x='name'
#                ,y='world_sales'
                 #,hue = 'platform'
#                ,data=data_2016
#                ,boxprops=dict(alpha=.3)
#               )
plt.xticks(rotation=65, horizontalalignment='right');
#ax = sea.barplot(x='name',y='world_sales', hue = 'platform', data=data_2016, alpha=.9)
sea.barplot(x='name',y='world_sales', hue = 'platform', data=data_2016, alpha=.9);

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> На мой взгляд, график перегружен - лучше выбрать что-то одно, или barplot, или boxplot.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Тут я тоже довольно долго играла с разными вариантами, но почему-то пришла к довольно несвойственному для меня перегруженному варианту, на самом деле тоже всегда склоняюсь к более легким графикам
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  👍
# </div>

# %%
data_2016
# Out:
#                               name platform  year_of_release         genre  \
# 0                          fifa 17      PS4             2016        Sports
# 1                 pokemon sun/moon      3DS             2016  Role-Playing
# 2       uncharted 4: a thief's end      PS4             2016       Shooter
# 3   call of duty: infinite warfare      PS4             2016       Shooter
# 4                    battlefield 1      PS4             2016       Shooter
# 5        tom clancy's the division      PS4             2016       Shooter
# 6                          fifa 17     XOne             2016        Sports
# 7   call of duty: infinite warfare     XOne             2016       Shooter
# 8                  far cry: primal      PS4             2016        Action
# 9                    battlefield 1     XOne             2016       Shooter
# 10       tom clancy's the division     XOne             2016       Shooter
# ...

# %% [markdown]
# **Вывод:**
#
# В тройке игр-лидиров по продажам копий только одна универсальная (по платформам игра) fifa17, остальные игры предназначены только для одной платформы, но в целом видна тенденция того, что чтобы попасть в топ по продажам нужно или сделать качественную игру для какой-то конкретной платформы (популярной в текущих реалиях) или выпустить платформу на две конкурирующие платформы консолий + в последствии запустить ее на ПК.
#
# На сам деле тут вопрос ресурсов компании, если разработчик может себе позволить разработку игры паралельно на двух/трех движках, то так и делают, если же нет выбирается та платформа, аудитория которой с большей готовностью приобретет игру, а вот тут все индивидуально, может быть и так, что сначаа выгоднее будет выпустить игру для ПК гейменга, а уже потом переносить на движек Xbox или PS.
#
# Особником тут будут идти игры для партативных косолей - так как это отдельная ниша пользователей, хотя такая игра и вошла в топ, это скорее исключение чем правило

# %% [markdown]
# **Корреляция оценки на продажи копий игр внутри платформы PS4 и 3DS**

# %% [markdown]
# ~Так как оценка пользователей содержит много пропусков, а оценка критивов 0 - проверим корелячию и с ними и без них~
#
# Исключим из проверки корреляции значения оценки критиков 0 и оценки пользователя -1, так как эти значения мы использовали для заполнения пропусков

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Здесь следует проанализировать данные строго без значений, на которые были заменены пропуски.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: без исключения даных смотрела на корреляцию исключительно для сравнения и оценки, что нужно исключить, вероятно такой код в будующем не стоит оставлять в финальном варианте
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  👍
# </div>

# %%
#data_relevant.loc[(data_relevant['platform'] == 'PS4'),['critic_score','user_score','world_sales']].corr()

# %%
#pd.plotting.scatter_matrix(data_relevant.loc[(data_relevant['platform'] == 'PS4'),['critic_score','user_score','world_sales']]
#                           ,figsize = (15,15)
#                           ,color='darkblue');

# %%
data_corr = data_relevant.loc[
    (data_relevant['platform'] == 'PS4') & 
                  (data_relevant['user_score'] != -1) & 
                  (data_relevant['critic_score'] != 0)
                  ,['critic_score','user_score','world_sales']]
data_corr.corr()
# Out:
#               critic_score  user_score  world_sales
# critic_score      1.000000    0.546434     0.401903
# user_score        0.546434    1.000000    -0.043186
# world_sales       0.401903   -0.043186     1.000000

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Вижу, что ты исключаешь пропуски в оценках пользователей, это правильно. Но разве у тебя не было аналогичной замены в оценках критиков?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Логично было их исключить, видимо не дажала этот момент, но ведь не бывает идеальных решений🤔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  Теперь код выглядит более корректным.
# </div>

# %%
pd.plotting.scatter_matrix(data_corr,figsize = (15,15),color='darkblue');

# %%
data_corr_3DS = data_relevant.loc[
    (data_relevant['platform'] == '3DS') & 
                  (data_relevant['critic_score'] != 0) & 
                  (data_relevant['user_score'] != -1)
                  ,['critic_score','user_score','world_sales']]
data_corr_3DS.corr()
# Out:
#               critic_score  user_score  world_sales
# critic_score      1.000000    0.862485     0.284686
# user_score        0.862485    1.000000     0.279850
# world_sales       0.284686    0.279850     1.000000

# %%
pd.plotting.scatter_matrix(data_corr_3DS,figsize = (15,15),color='darkblue');

# %% [markdown]
# **Вывод:**
#
# Есть прямая связь между оценкой критиков и пользователей (как правило высокие оценки тут совпадают), но бывают и исключения.
#
# А вот продажи с оценками пользователей связаны меньше чем с оценкой критиков, и это нормально поскольку встречаются игры для узкого круга которые могут получить высокии оценки и избежать "случайных" недовольных игроков, а есть игры сбольшим игровым сообществом, которые могут поймить таких игроков и получить занижение оценки (до средних значений).
#
# Чем уже специфика платформы и направленее игры тем сильнее связь между оценкой критика и оценкой пользователей и продажами.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Пожалуйста, откорректируй актуальный период и внеси необходимые изменения в этом пункте.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Изменения внесены 👌
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  Выводы верные, можно было еще описать значения коэффициентов корреляции и что они означают.
# </div>

# %% [markdown]
# #### Распределение игр по жанрам

# %% [markdown]
# Задачи:
#
# - [x] Посмотреть на общее распределение игр по жанрам.
# - [x] Что можно сказать о самых прибыльных жанрах?
# - [x] Выделяются ли жанры с высокими и низкими продажами?

# %%
data_genre = (data_relevant.pivot_table('world_sales', 'genre', aggfunc='median')
.sort_values(by='world_sales', ascending=False))
data_genre
# Out:
#               world_sales
# genre
# Shooter             0.515
# Sports              0.180
# Platform            0.140
# Fighting            0.125
# Role-Playing        0.110
# Simulation          0.100
# Action              0.090
# Misc                0.090
# Racing              0.090
# Strategy            0.060
# Puzzle              0.045
# Adventure           0.030

# %%
data_genre_2016 = (data_relevant[data_relevant['year_of_release'] == 2016]
                        .pivot_table('world_sales', 'genre', aggfunc='median')
                        .sort_values(by='world_sales', ascending=False))
data_genre_2016
# Out:
#               world_sales
# genre
# Shooter             0.240
# Role-Playing        0.120
# Sports              0.120
# Platform            0.100
# Fighting            0.085
# Strategy            0.060
# Action              0.050
# Racing              0.050
# Misc                0.040
# Simulation          0.025
# Adventure           0.020
# Puzzle              0.010

# %%
fig, ax = plt.subplots()
(data_genre
 .plot(kind='barh' ,figsize=(10,10),color='darkblue', ax = ax));
ax2 = ax.twinx()
(data_genre_2016
 .plot(kind='barh' ,figsize=(10,10),color='blue', ax = ax2)
 .set(title='Распределение продаж копий игр по жанрам в периоде 2014-2016 и в 2016 годы'));

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Так как мы изменили подход с оценки сумарных продаж, на оценку медианных продаж, то нужно учесть и количество выпускаемых игр по жанрам что бы понимать рынок в целом, ведь если медиана не поменялась, то количественно мог быть рост выпуска игр.
# </div>

# %%
data_genre = (data_relevant.pivot_table('world_sales', 'genre', aggfunc='count')
.sort_values(by='world_sales', ascending=False))
data_genre_2016 = (data_relevant[data_relevant['year_of_release'] == 2016]
                        .pivot_table('world_sales', 'genre', aggfunc='count')
                        .sort_values(by='world_sales', ascending=False))
fig, ax = plt.subplots()
(data_genre
 .plot(kind='barh' ,figsize=(10,10),color='darkblue', ax = ax));
ax2 = ax.twinx()
(data_genre_2016
 .plot(kind='barh' ,figsize=(10,10),color='blue', ax = ax2)
 .set(title='Распределение продаж копий игр по жанрам в периоде 2014-2016 и в 2016 годы'));

# %% [markdown]
# **Вывод:**
#     Если сравнивать распределение по жанрам в периоды с ~2005~ 2014 по 2016 и ~с~ 2015 ~по 2016~ видна следующяя тенденция:
#
# - в 5ке лидиров стремительно поднялись РПГ игры как по популярности среди игроков, так и по выпуску новых игр в жанре (интересно посмотреть как дела обстоят сейчас)
# - ~экшен сдал позицию безоговорочного лидира и ушёл на вторую строчку~ экшен не входит в 5 лидиров по продоваемости копий на игру, но вот по числу выпускаемых игр это безусловный лидир
# - шутеры стали более популярны
# - по числу проданых копий на 1 игру и по количеству выпущенных игр 5 лидиров сильно не поменялась
# - ~в целом многие жанры стали забываться, обозначив безусловную 4 лидиров~
#
# Если смотреть глобально, то как и в кино и книга, в видиоигровой индустрии давно произошло смешение жанров и такое грубое разделение сейчас выглядит устаревшим.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Здорово, что отдельно смотришь на два последних года, здесь надо использовать откорректированный актуальный период.  👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b> Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Изменения внесены 👌
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b>  👍
# </div>

# %% [markdown]
# ### Портрет пользователя каждого региона

# %% [markdown]
# Определить для пользователя каждого региона (NA, EU, JP):
#
# - [x] Самые популярные платформы (топ-5). Описать различия в долях продаж.
# - [x] Самые популярные жанры (топ-5). Пояснить разницу.
# - [x] Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# ~Что бы построить портрет актуального пользователя используем только самые свежие данные. Так как данные за 2016 год вероятно не полные, рассмотрим только 2015 и 2016 год:~

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Здесь снова надо откорректировать актуальный период, и использовать его. 2015-2016 - не совсем оптимальный вариант для исследования актуальных для нашей задачи данных, так как данные за 2016 год не полные. Лучше взять период от 3 до 5 лет.
# </div>

# %%
#data_2015_2016 = data.loc[data['year_of_release'] >= 2015].reset_index(drop=True)
#data_2015_2016.head()

# %% [markdown]
# #### Топ5 платформ

# %%
top5_platform= (data_relevant
                           .pivot_table(['na_sales','eu_sales','jp_sales','other_sales','world_sales'], 
                                        ['platform'], 
                                        aggfunc='sum')
                           .sort_values(by='world_sales', ascending=False))
top5_platform = top5_platform.head(5)
top5_platform
# Out:
#           eu_sales  jp_sales  na_sales  other_sales  world_sales
# platform
# PS4         130.04     15.02     98.61        44.48       288.15
# XOne         46.25      0.32     81.27        12.52       140.36
# 3DS          16.12     44.24     22.64         3.68        86.68
# PS3          25.54     11.22     22.05         9.37        68.18
# X360         15.49      0.08     28.30         4.35        48.22

# %%
fig, axis = plt.subplots(2,2, figsize=(15,15))
top5_platform.loc[:,'eu_sales'].plot.pie(ax=axis[0,0]);
top5_platform.loc[:,'jp_sales'].plot.pie(ax=axis[0,1]);
top5_platform.loc[:,'na_sales'].plot.pie(ax=axis[1,0]);
top5_platform.loc[:,'world_sales'].plot.pie(ax=axis[1,1]);

# %%
#напишим функцию для преобразования столбцов
def delta(row):
    row['eu_sales'] = round(row['eu_sales']/row['world_sales'],2)
    row['jp_sales'] = round(row['jp_sales']/row['world_sales'],2)
    row['na_sales'] = round(row['na_sales']/row['world_sales'],2)
    row['other_sales'] = round(row['other_sales']/row['world_sales'],2)
    return row


top5_platform_delta = top5_platform.copy()
top5_platform_delta.apply(delta, axis=1)

top5_platform_delta
# Out:
#           eu_sales  jp_sales  na_sales  other_sales  world_sales
# platform
# PS4           0.45      0.05      0.34         0.15       288.15
# XOne          0.33      0.00      0.58         0.09       140.36
# 3DS           0.19      0.51      0.26         0.04        86.68
# PS3           0.37      0.16      0.32         0.14        68.18
# X360          0.32      0.00      0.59         0.09        48.22

# %% [markdown]
# Даные по платформам ТОП5
# - PS4 - PlayStation 4 приставка компании Sony, Япония, наиболее популярны в Европе
# - XOne - Xbox One приставка компании Microsoft, США, наиболее популярны на родине, а вот в Японии данная приставка явно не снискала успеха
# - 3DS -  портативная игровая консоль компании Nintendo, Япония, наиболее популярны на родине
# - ~WiiU - 8-ое поколение приставок компании Nintendo, Япония. , наиболее популярны в США~
# - PS3 - PlayStation 3 приставка компании Sony, Япония, наиболее популярны в Европе
# - X360 - Xbox 360 приставка компании Microsoft, США, наиболее популярны на родине, а вот в Японии данная приставка явно не снискала успеха
#
# ~Распределение на ПК логично с весомым перевесом на европу, а вот в японии в принципе ПК предпочитают использовать для работы~

# %% [markdown]
# #### Топ5 жанров

# %%
top5_genre = (data_relevant
                           .pivot_table(['na_sales','eu_sales','jp_sales','other_sales','world_sales'], 
                                        ['genre'], 
                                        aggfunc='sum')
                           .sort_values(by='world_sales', ascending=False))
top5_genre = top5_genre.head()
top5_genre
# Out:
#               eu_sales  jp_sales  na_sales  other_sales  world_sales
# genre
# Action           74.68     29.58     72.53        22.57       199.36
# Shooter          65.52      4.87     79.02        21.53       170.94
# Sports           45.73      3.26     46.13        14.36       109.48
# Role-Playing     28.17     31.16     33.47         8.64       101.44
# Misc             12.86      5.61     15.05         4.03        37.55

# %%
fig, axis = plt.subplots(2,2, figsize=(15,15))
top5_genre.loc[:,'eu_sales'].plot.pie(ax=axis[0,0]);
top5_genre.loc[:,'jp_sales'].plot.pie(ax=axis[0,1]);
top5_genre.loc[:,'na_sales'].plot.pie(ax=axis[1,0]);
top5_genre.loc[:,'world_sales'].plot.pie(ax=axis[1,1]);

# %%
top5_genre_delta = top5_genre.copy()
top5_genre_delta.apply(delta, axis=1)

top5_genre_delta
# Out:
#               eu_sales  jp_sales  na_sales  other_sales  world_sales
# genre
# Action            0.37      0.15      0.36         0.11       199.36
# Shooter           0.38      0.03      0.46         0.13       170.94
# Sports            0.42      0.03      0.42         0.13       109.48
# Role-Playing      0.28      0.31      0.33         0.09       101.44
# Misc              0.34      0.15      0.40         0.11        37.55

# %% [markdown]
# Shooter(шутер) и Action(экшен) оказались значительно популярнее остальных жанров, однако шутеры совсем не популярны в Японии в то время как экшен распределен примерно в равных долях по регионам, но явно наиболее популярен в Японии.
# Спорт так же остался обделен пользователями из японии.
# Role-Playing (РПГ) имеет схожие доли во всех регионах, кроме Японии где занимает вторую строчку.
# Misc Аркады) сильно просидают по сравнению с 4 строчкой и явно не часто задерживаются на 5.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠ Комментарий ревьюера:</b> Результаты не совсем корректные, вероятно, из-за неверно определенного периода для анализа.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Изменения внесены в период, но вот результаты не сильно поменялись, может что-то упустили?👌
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 2:</b> Теперь все хорошо, изменения особенно заметны в графиках по Японии.
# </div>

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в отдельном регионе

# %%
fig, axis = plt.subplots(2,2, figsize=(15,10))
sea.barplot(y='na_sales', x='rating', data = data_relevant,estimator=sum, ax=axis[0,0]);
sea.barplot(y='eu_sales', x='rating', data = data_relevant,estimator=sum, ax=axis[0,1]);
sea.barplot(y='jp_sales', x='rating', data = data_relevant,estimator=sum, ax=axis[1,0]);
sea.barplot(y='world_sales', x='rating', data = data_relevant,estimator=sum, ax=axis[1,1]);

# %% [markdown]
# В Японии рейтинг ESRB не влияет на выбор игроков. В США и Европе распределение с хоже с общемировыми тенденциями.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b>  👍
# </div>

# %% [markdown]
# **Вывод:**
#     После детального разбора "свежих" свежих данных пожно составить примерно такие портреты пользователей:
#
# - Европа - пользователи предпочитают играть на PS4 в шутеры и экшен (что характерно даной платформы) и склонны доверять рейтингу ESRB
# - США - пользователи предпочитают играть на PS4 и Xbox One  в шутеры и экшен (что характерно даных платформ) и склонны доверять рейтингу ESRB
# - Япония - пользователи играют на партотивных 3DS в экшен или РПГ и не соовершенно не склоны доверять рейтенгу ESRB
# - Мир - в целом пользователи предпочитают играть на PS4 и Xbox One, что говорит о том, что игроки Японии занимают только 3 место, и играют в шутеры и экшен примерно в одинаковой пропорции.

# %% [markdown]
# ### Проверка гипотез
#
# **Гипотеза:**
#     Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# ```
# H_0: Рейтинг (user_score) игр для платформы  Xbox One = рейтинг (user_score) игр для платформы PC`
# H_1: Рейтинг (user_score) игр для платформы  Xbox One ≠ рейтинг (user_score) игр для платформы PC`
# alpha = 0.05
# ```

# %%
results =  st.ttest_ind(
    data_relevant[(data_relevant['user_score'] != -1) & 
                  (data_relevant['platform'] =='XOne')]['user_score'], 
    data_relevant[(data_relevant['user_score'] != -1) & 
                  (data_relevant['platform'] =='PC')]['user_score'],
    )# results = вызов метода для проверки гипотезы

alpha = 0.05# alpha = значение уровня значимости

print(results.pvalue)# вывод значения p-value на экран 
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу") # условный оператор с выводом строки с ответом
# Out:
# 0.10450507919348415
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b> 1) Ты используешь в коде исходный датасет (data), а фильтр по платформе делаешь по data_relevant. Сохрани срез датасета по актуальному периоду в соответствующем разделе проекта и во всем дальнейшем проекте используй только его.
#
# 2) Не корректные результаты теста, вероятно, из-за неверно определенного актуального периода.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Изменения внесены👌
# </div>

# %%
#Проверим среднее на ПК в данных
data_relevant[(data_relevant['platform'] =='PC') 
              & (data_relevant['user_score'] != -1)]['user_score'].mean()
# Out:
# 6.298360655737705

# %%
#Проверим среднее на Xbox One в данных
data_relevant[(data_relevant['platform'] =='XOne') & 
              (data_relevant['user_score'] != -1)]['user_score'].mean()
# Out:
# 6.594545454545456

# %% [markdown]
# **Гипотеза:**
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные
#
# ```
# H_0: Рейтинг (user_score) игр жанра Action = рейтинг (user_score) игр жанра Sports`
# H_1: Рейтинг (user_score) игр жанра Action ≠ рейтинг (user_score) игр жанра Sports`
# alpha = 0.05
# ```

# %%
results =  st.ttest_ind(
    data_relevant[(data_relevant['genre'] =='Action') & 
                  (data_relevant['user_score'] != -1)]['user_score'], 
    data_relevant[(data_relevant['genre'] =='Sports') & 
                  (data_relevant['user_score'] != -1)]['user_score'],
    equal_var = False
    )# results = вызов метода для проверки гипотезы

alpha = 0.05# alpha = задайте значение уровня значимости

print(results.pvalue)# вывод значения p-value на экран 
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу") # условный оператор с выводом строки с ответом
# Out:
# 1.1825550382644557e-14
# Отвергаем нулевую гипотезу

# %%
#Проверим среднее для экшена в данных
data_relevant[(data_relevant['genre'] =='Action') & 
              (data_relevant['user_score'] != -1)]['user_score'].mean()
# Out:
# 6.760606060606061

# %%
#Проверим среднее для спорта в данных
data_relevant[(data_relevant['genre'] =='Sports') & 
              (data_relevant['user_score'] != -1)]['user_score'].mean()
# Out:
# 5.2251968503937

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Отлично, что дополнительно посчитала средние значения для жанров - так мы видим, насколько велики различия между ними 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера:</b>  Здесь то же самое - определись с актуальным периодом, сделай срез по нему и используй только эти данные.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v1: Изменения внесены👌
# </div>

# %% [markdown]
# **Вывод:**
# Средние пользовательские рейтинги платформ Xbox One и PC стремятся быть одинаковыми ближе к актуальному периоду.
#
# Средние пользовательские рейтинги жанров Action  и Sports стремятся быть разными.
#
# Уровень значимости был принят стандартный (0.05)
# Обе гипотезы двухсторонии.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера № 2:</b> При доработке проекта ты заменила пропуски в user_score на значение-заглушку, но не удалила его из среза перед тестированием.  Это замечание относится к обоим тестам.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v2: Изменения внесены👌
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Комментарий ревьюера № 3:</b>  Татьяна, пожалуйста, посмотри, что мы здесь тестируем и надо ли нам убирать пропуски (=заглушки) по critic_score?  Почему ты вдруг решила их убрать тоже, ведь в предыдущем варианте этого не было? Мы тестируем различия в средних пользовательских рейтингах (user_score), если мы начнем удалять записи с пропусками в других признаках, то потеряем много данных.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v3: Если смотреть с точки зрения краткости написания кода, условие лишние, убрать и оценки критиков = 0 решила так как это тоже жамешенное значение, хотя на конкретное иследование и не влияет, так получились меньшие выборки, но даже при таких выборках результаты иследования остались неизменны, что подтверждает то,что итоговый результат можно счить достоверным.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера № 4:</b> Результат теста не изменился, но результаты теста нельзя назвать достоверными по причине больших потерь в данных. Можешь сравнить % потерь в данных при удалении пропусков только по user_score и то, что получилось после удаления пропусков в двух признаках. Это довольно грубая ошибка, пожалуйста, постарайся не допускать ее в будущих проектах.
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Для анализа был предоставлен довольно "чистый" датасет, жаль что данные не совсем актуальны и содержат лишь информацию до 2016 года.
#
# Для того что бы составить прогноз по видиоиграм и не только на следующий год лучше использовать данные за два (три) последних года, таким образом мы избежим влияния устаревших платформ (данных) на прогноз и сможем спрогназировать рост/падение продаж (или других параметров).
#
# В целом игровая индустрия сильно зависит от развития технологий и для грамотного прогнозирования стоит учитывать новые тенденции, так же последнее время на ситуацию в целом и на видиогейменг в частности повлияли и внешние факторы.
#
# Так же смело можно сказать что ПК "гейменг жил,жив и будет жить"и эта та сама лошадка которая всегда добегает до финиша, к тому же за последнее время сильно выросло техническое оснощение ПК и многие разработчики адаптировали свои игры под ПК (ну или используются симуляторы), а так же расцветает эра онлайн игровых серверов для тех кто не может себе позволить хороший игровой ПК или консоль.
#
# В зависимости от регионов можно выделить определенные предпочтения, но почти везде лидирует экшен по количеству проданых копий ( в большей степень потому что экшен игр выходит в разы больше остальных жанров). Платформы популярны не равномерно по регионам, но в целом США и Европа имеют приблизительно идентичные предпочтения, а вот если нацелиться на Японию, то стоит адоптироваться именно под предпочтения этого региона.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Хорошие аналитические выводы. Пожалуйста, не забудь откорректировать выводы после всех изменений.
# </div>

# %%
#Топ игр 2015-2016 года на ПК (во что стоит поиграть, если еще не успел(а)😉 - типо для себя)
data_gamе_name = (data_relevant[
    (data_relevant['year_of_release'] >= 2015) & 
    (data_relevant['world_sales'] >= 1) & 
    (data_relevant['genre'].isin(['Action','Strategy','Role-Playing']))]
                            .pivot_table(values ='world_sales', 
                                         index =['genre','name'], 
                                         aggfunc='sum')
                            .sort_values(by=['genre','world_sales'], ascending=False))
data_gamе_name
# Out:
#                                                         world_sales
# genre        name
# Role-Playing fallout 4                                        12.67
#              pokemon sun/moon                                  7.14
#              the witcher 3: wild hunt                          5.27
#              the elder scrolls online                          3.03
#               fire emblem fates                                1.67
#              dark souls iii                                    1.66
#              the elder scrolls v: skyrim                       1.32
#              pokemon super mystery dungeon                     1.25
# Action       batman: arkham knight                             5.45
#              assassin's creed syndicate                        4.68
#              uncharted: the nathan drake collection            4.62
#              metal gear solid v: the phantom pain              3.42
#              dying light                                       3.38
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔ Комментарий ревьюера:</b> Интересный список получился 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>ОБЩИЙ КОММЕНТАРИЙ:</b> Татьяна, в целом очень хорошая работа, есть очень хорошие решения и аналитически грамотные комментарии. Чувствуется, что у тебя уже есть опыт проведения аналитических исследований:) Очень понравилось, что ты стараешься смотреть на данные с разных сторон и в разных срезах.  К сожалению,  есть некоторые замечания, которые надо исправить. Думаю, что для тебя это будет несложно. Жду изменений, удачи! </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>ОБЩИЙ КОММЕНТАРИЙ № 2:</b> Татьяна, теперь почти все хорошо, но есть небольшая ошибка в разделе с тестированием гипотез - не включай в срез для тестирования значения, на которые ты заменила пропуски в user_score, иначе ты получаешь некорректные результаты теста. Жду исправлений!</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>ОБЩИЙ КОММЕНТАРИЙ № 4:</b> Татьяна, замечания доработаны и проект можно принять :)</div>
